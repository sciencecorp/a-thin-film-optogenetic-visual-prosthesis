# %%
# figure 5d - single trial time-frequency plot
import matplotlib.pyplot as plt
import numpy as np
import scipy
import pickle

file = '/Volumes/Science/Biology/Paper_data_and_code/Figure 5/flexled_rabbit01.pkl' 
with open(file, 'rb') as h:
    flexled01 = pickle.load(h)
    
file = '/Volumes/Science/Biology/Paper_data_and_code/Figure 5/flexled_rabbit02.pkl' 
with open(file, 'rb') as h:
    flexled02 = pickle.load(h)
    
cmap='magma'
fig,ax=plt.subplot_mosaic([["left","top right"],["left","bottom right"]],layout='constrained')
fig.set_size_inches(4.2,4)
f = np.linspace(10,300,73)
t = np.arange(-200,1000,1)

#m = np.mean(cwt_norm,axis=-1)
m = flexled02['cwt_norm']
zf = 4
dd = scipy.ndimage.zoom(m, [zf,zf])
fx = scipy.ndimage.zoom(t,zf)
fy = scipy.ndimage.zoom(f,zf)

pcm = ax['left'].pcolormesh(fx,fy,dd,cmap=cmap)

#ax.pcolormesh(t,f,m)
ax['left'].set_ylim([10,100])
ax['left'].plot([0,0],ax['left'].get_ylim(),'w',lw=2)
ax['left'].set_xlabel('Time from stim on (ms)')
ax['left'].set_ylabel('Frequency (Hz)')
ax['left'].set_xlim([-200,400])
ax['left'].spines['top'].set_visible(False)
ax['left'].spines['right'].set_visible(False)
plt.colorbar(pcm,ax=ax['left'],fraction=1, pad=-0.125)

ind = np.where(f>=20)[0][0]
ind2 = np.where(f<=80)[0][-1]
print(ind,ind2)
ax['top right'].plot(t,np.mean(m[ind:ind2,:],axis=0),'b',lw=2)
ax['top right'].plot([0,0],ax['top right'].get_ylim(),'k',lw=2)
ax['top right'].set_ylabel('Norm. $\gamma$ (20-80 Hz, mV$^{2}$)')
ax['top right'].spines['top'].set_visible(False)
ax['top right'].spines['right'].set_visible(False)
ax['top right'].set_xlim([-200,400])

ind = np.where(f<=50)[0][-1]

#ax['bottom right'].plot(t,np.mean(m[:ind,:],axis=0),'b',lw=2)
ax['bottom right'].plot(t,flexled02['wide'],'b',lw=2)
ax['bottom right'].plot([0,0],ax['bottom right'].get_ylim(),'k')
ax['bottom right'].spines['top'].set_visible(False)
ax['bottom right'].spines['right'].set_visible(False)
ax['bottom right'].set_ylabel('Raw LFP (mV)')
ax['bottom right'].set_xlabel('Time from stim')
ax['bottom right'].set_xlim([-200,400])
# Out:
# 3 17
# (-200.0, 400.0)

# %%
# Figure 5e - grid wide time series: top plot
vmin = 0
vmax = 40
fig,ax = plt.subplots(1,10,layout='constrained')
fig.set_size_inches(8,2.5)
mm = np.max(flexled01['gamma'][:,:,150:200],axis=-1)

zf = 2
dd = scipy.ndimage.zoom(mm, [zf,zf])
fx = scipy.ndimage.zoom(range(4),zf)
fy = scipy.ndimage.zoom(range(8),zf)

pcm = ax[0].pcolormesh(fx,fy,dd,cmap=cmap,vmin=vmin,vmax=vmax)
ax[0].axis('equal')
ax[0].set_xlabel('M<---->L')
ax[0].set_ylabel('P<----->A')
ax[0].spines['top'].set_visible(False)
ax[0].spines['right'].set_visible(False)
ax[0].spines['bottom'].set_visible(False)
ax[0].spines['left'].set_visible(False)
ax[0].set_xticks([])
ax[0].set_yticks([])
ax[0].set_title('-50')
##

mm = np.max(flexled01['gamma'][:,:,200:250],axis=-1)

zf = 2
dd = scipy.ndimage.zoom(mm, [zf,zf])
fx = scipy.ndimage.zoom(range(4),zf)
fy = scipy.ndimage.zoom(range(8),zf)

pcm = ax[1].pcolormesh(fx,fy,dd,cmap=cmap,vmin=vmin,vmax=vmax)
ax[1].axis('equal')
#ax[1].set_xlabel('M<---->L')
#ax[1].set_ylabel('P<----->A')
ax[1].spines['top'].set_visible(False)
ax[1].spines['right'].set_visible(False)
ax[1].spines['bottom'].set_visible(False)
ax[1].spines['left'].set_visible(False)
ax[1].set_xticks([])
ax[1].set_yticks([])
ax[1].set_title('+0')
##
mm = np.max(flexled01['gamma'][:,:,250:300],axis=-1)

zf = 2
dd = scipy.ndimage.zoom(mm, [zf,zf])
fx = scipy.ndimage.zoom(range(4),zf)
fy = scipy.ndimage.zoom(range(8),zf)

pcm = ax[2].pcolormesh(fx,fy,dd,cmap=cmap,vmin=vmin,vmax=vmax)
ax[2].axis('equal')
#ax[2].set_xlabel('M<---->L')
#ax[2].set_ylabel('P<----->A')
ax[2].spines['top'].set_visible(False)
ax[2].spines['right'].set_visible(False)
ax[2].spines['bottom'].set_visible(False)
ax[2].spines['left'].set_visible(False)
ax[2].set_xticks([])
ax[2].set_yticks([])
ax[2].set_title('+50')

##
mm = np.max(flexled01['gamma'][:,:,300:350],axis=-1)

zf = 2
dd = scipy.ndimage.zoom(mm, [zf,zf])
fx = scipy.ndimage.zoom(range(4),zf)
fy = scipy.ndimage.zoom(range(8),zf)

pcm = ax[3].pcolormesh(fx,fy,dd,cmap=cmap,vmin=vmin,vmax=vmax)
ax[3].axis('equal')
#ax[3].set_xlabel('M<---->L')
#ax[3].set_ylabel('P<----->A')
ax[3].spines['top'].set_visible(False)
ax[3].spines['right'].set_visible(False)
ax[3].spines['bottom'].set_visible(False)
ax[3].spines['left'].set_visible(False)
ax[3].set_xticks([])
ax[3].set_yticks([])
ax[3].set_title('+100')

##
mm = np.max(flexled01['gamma'][:,:,350:400],axis=-1)

zf = 2
dd = scipy.ndimage.zoom(mm, [zf,zf])
fx = scipy.ndimage.zoom(range(4),zf)
fy = scipy.ndimage.zoom(range(8),zf)

pcm = ax[4].pcolormesh(fx,fy,dd,cmap=cmap,vmin=vmin,vmax=vmax)
ax[4].axis('equal')
#ax[4].set_xlabel('M<---->L')
#ax[4].set_ylabel('P<----->A')
ax[4].spines['top'].set_visible(False)
ax[4].spines['right'].set_visible(False)
ax[4].spines['bottom'].set_visible(False)
ax[4].spines['left'].set_visible(False)
ax[4].set_xticks([])
ax[4].set_yticks([])
ax[4].set_title('+150')
##
mm = np.max(flexled01['gamma'][:,:,450:500],axis=-1)

zf = 2
dd = scipy.ndimage.zoom(mm, [zf,zf])
fx = scipy.ndimage.zoom(range(4),zf)
fy = scipy.ndimage.zoom(range(8),zf)

pcm = ax[5].pcolormesh(fx,fy,dd,cmap=cmap,vmin=vmin,vmax=vmax)
ax[5].axis('equal')
#ax[5].set_xlabel('M<---->L')
#ax[5].set_ylabel('P<----->A')
ax[5].spines['top'].set_visible(False)
ax[5].spines['right'].set_visible(False)
ax[5].spines['bottom'].set_visible(False)
ax[5].spines['left'].set_visible(False)
ax[5].set_xticks([])
ax[5].set_yticks([])
ax[5].set_title('+250')
##
mm = np.max(flexled01['gamma'][:,:,550:600],axis=-1)

zf = 2
dd = scipy.ndimage.zoom(mm, [zf,zf])
fx = scipy.ndimage.zoom(range(4),zf)
fy = scipy.ndimage.zoom(range(8),zf)

pcm = ax[6].pcolormesh(fx,fy,dd,cmap=cmap,vmin=vmin,vmax=vmax)
ax[6].axis('equal')
#ax[5].set_xlabel('M<---->L')
#ax[5].set_ylabel('P<----->A')
ax[6].spines['top'].set_visible(False)
ax[6].spines['right'].set_visible(False)
ax[6].spines['bottom'].set_visible(False)
ax[6].spines['left'].set_visible(False)
ax[6].set_xticks([])
ax[6].set_yticks([])
ax[6].set_title('+350')

##
mm = np.max(flexled01['gamma'][:,:,650:700],axis=-1)

zf = 2
dd = scipy.ndimage.zoom(mm, [zf,zf])
fx = scipy.ndimage.zoom(range(4),zf)
fy = scipy.ndimage.zoom(range(8),zf)

pcm = ax[7].pcolormesh(fx,fy,dd,cmap=cmap,vmin=vmin,vmax=vmax)
ax[7].axis('equal')
#ax[5].set_xlabel('M<---->L')
#ax[5].set_ylabel('P<----->A')
ax[7].spines['top'].set_visible(False)
ax[7].spines['right'].set_visible(False)
ax[7].spines['bottom'].set_visible(False)
ax[7].spines['left'].set_visible(False)
ax[7].set_xticks([])
ax[7].set_yticks([])
ax[7].set_title('+450')
##
mm = np.max(flexled01['gamma'][:,:,750:800],axis=-1)

zf = 2
dd = scipy.ndimage.zoom(mm, [zf,zf])
fx = scipy.ndimage.zoom(range(4),zf)
fy = scipy.ndimage.zoom(range(8),zf)

pcm = ax[8].pcolormesh(fx,fy,dd,cmap=cmap,vmin=vmin,vmax=vmax)
ax[8].axis('equal')
#ax[5].set_xlabel('M<---->L')
#ax[5].set_ylabel('P<----->A')
ax[8].spines['top'].set_visible(False)
ax[8].spines['right'].set_visible(False)
ax[8].spines['bottom'].set_visible(False)
ax[8].spines['left'].set_visible(False)
ax[8].set_xticks([])
ax[8].set_yticks([])
ax[8].set_title('+550')
##
mm = np.max(flexled01['gamma'][:,:,850:900],axis=-1)

zf = 2
dd = scipy.ndimage.zoom(mm, [zf,zf])
fx = scipy.ndimage.zoom(range(4),zf)
fy = scipy.ndimage.zoom(range(8),zf)

pcm = ax[9].pcolormesh(fx,fy,dd,cmap=cmap,vmin=vmin,vmax=vmax)
ax[9].axis('equal')
#ax[5].set_xlabel('M<---->L')
#ax[5].set_ylabel('P<----->A')
ax[9].spines['top'].set_visible(False)
ax[9].spines['right'].set_visible(False)
ax[9].spines['bottom'].set_visible(False)
ax[9].spines['left'].set_visible(False)
ax[9].set_xticks([])
ax[9].set_yticks([])
ax[9].set_title('+650')
fig.colorbar(pcm,ax=ax[2],fraction=0.07, pad=-0.050)

# %%
# Figure 5e - grid wide time series: top plot
vmin = -0.4
vmax = 2.4
fig,ax = plt.subplots(1,10,layout='constrained')
fig.set_size_inches(8,2.5)
mm = np.max(flexled02['gamma'][:,:,150:200],axis=-1)

zf = 2
dd = scipy.ndimage.zoom(mm, [zf,zf])
fx = scipy.ndimage.zoom(range(4),zf)
fy = scipy.ndimage.zoom(range(8),zf)

pcm = ax[0].pcolormesh(fx,fy,dd,cmap=cmap,vmin=vmin,vmax=vmax)
ax[0].axis('equal')
ax[0].set_xlabel('M<---->L')
ax[0].set_ylabel('P<----->A')
ax[0].spines['top'].set_visible(False)
ax[0].spines['right'].set_visible(False)
ax[0].spines['bottom'].set_visible(False)
ax[0].spines['left'].set_visible(False)
ax[0].set_xticks([])
ax[0].set_yticks([])
ax[0].set_title('-50')
##

mm = np.max(flexled02['gamma'][:,:,200:250],axis=-1)

zf = 2
dd = scipy.ndimage.zoom(mm, [zf,zf])
fx = scipy.ndimage.zoom(range(4),zf)
fy = scipy.ndimage.zoom(range(8),zf)

pcm = ax[1].pcolormesh(fx,fy,dd,cmap=cmap,vmin=vmin,vmax=vmax)
ax[1].axis('equal')
#ax[1].set_xlabel('M<---->L')
#ax[1].set_ylabel('P<----->A')
ax[1].spines['top'].set_visible(False)
ax[1].spines['right'].set_visible(False)
ax[1].spines['bottom'].set_visible(False)
ax[1].spines['left'].set_visible(False)
ax[1].set_xticks([])
ax[1].set_yticks([])
ax[1].set_title('+0')
##
mm = np.max(flexled02['gamma'][:,:,250:300],axis=-1)

zf = 2
dd = scipy.ndimage.zoom(mm, [zf,zf])
fx = scipy.ndimage.zoom(range(4),zf)
fy = scipy.ndimage.zoom(range(8),zf)

pcm = ax[2].pcolormesh(fx,fy,dd,cmap=cmap,vmin=vmin,vmax=vmax)
ax[2].axis('equal')
#ax[2].set_xlabel('M<---->L')
#ax[2].set_ylabel('P<----->A')
ax[2].spines['top'].set_visible(False)
ax[2].spines['right'].set_visible(False)
ax[2].spines['bottom'].set_visible(False)
ax[2].spines['left'].set_visible(False)
ax[2].set_xticks([])
ax[2].set_yticks([])
ax[2].set_title('+50')

##
mm = np.max(flexled02['gamma'][:,:,300:350],axis=-1)

zf = 2
dd = scipy.ndimage.zoom(mm, [zf,zf])
fx = scipy.ndimage.zoom(range(4),zf)
fy = scipy.ndimage.zoom(range(8),zf)

pcm = ax[3].pcolormesh(fx,fy,dd,cmap=cmap,vmin=vmin,vmax=vmax)
ax[3].axis('equal')
#ax[3].set_xlabel('M<---->L')
#ax[3].set_ylabel('P<----->A')
ax[3].spines['top'].set_visible(False)
ax[3].spines['right'].set_visible(False)
ax[3].spines['bottom'].set_visible(False)
ax[3].spines['left'].set_visible(False)
ax[3].set_xticks([])
ax[3].set_yticks([])
ax[3].set_title('+100')

##
mm = np.max(flexled02['gamma'][:,:,350:400],axis=-1)

zf = 2
dd = scipy.ndimage.zoom(mm, [zf,zf])
fx = scipy.ndimage.zoom(range(4),zf)
fy = scipy.ndimage.zoom(range(8),zf)

pcm = ax[4].pcolormesh(fx,fy,dd,cmap=cmap,vmin=vmin,vmax=vmax)
ax[4].axis('equal')
#ax[4].set_xlabel('M<---->L')
#ax[4].set_ylabel('P<----->A')
ax[4].spines['top'].set_visible(False)
ax[4].spines['right'].set_visible(False)
ax[4].spines['bottom'].set_visible(False)
ax[4].spines['left'].set_visible(False)
ax[4].set_xticks([])
ax[4].set_yticks([])
ax[4].set_title('+150')
##
mm = np.max(flexled02['gamma'][:,:,450:500],axis=-1)

zf = 2
dd = scipy.ndimage.zoom(mm, [zf,zf])
fx = scipy.ndimage.zoom(range(4),zf)
fy = scipy.ndimage.zoom(range(8),zf)

pcm = ax[5].pcolormesh(fx,fy,dd,cmap=cmap,vmin=vmin,vmax=vmax)
ax[5].axis('equal')
#ax[5].set_xlabel('M<---->L')
#ax[5].set_ylabel('P<----->A')
ax[5].spines['top'].set_visible(False)
ax[5].spines['right'].set_visible(False)
ax[5].spines['bottom'].set_visible(False)
ax[5].spines['left'].set_visible(False)
ax[5].set_xticks([])
ax[5].set_yticks([])
ax[5].set_title('+250')
##
mm = np.max(flexled02['gamma'][:,:,550:600],axis=-1)

zf = 2
dd = scipy.ndimage.zoom(mm, [zf,zf])
fx = scipy.ndimage.zoom(range(4),zf)
fy = scipy.ndimage.zoom(range(8),zf)

pcm = ax[6].pcolormesh(fx,fy,dd,cmap=cmap,vmin=vmin,vmax=vmax)
ax[6].axis('equal')
#ax[5].set_xlabel('M<---->L')
#ax[5].set_ylabel('P<----->A')
ax[6].spines['top'].set_visible(False)
ax[6].spines['right'].set_visible(False)
ax[6].spines['bottom'].set_visible(False)
ax[6].spines['left'].set_visible(False)
ax[6].set_xticks([])
ax[6].set_yticks([])
ax[6].set_title('+350')

##
mm = np.max(flexled02['gamma'][:,:,650:700],axis=-1)

zf = 2
dd = scipy.ndimage.zoom(mm, [zf,zf])
fx = scipy.ndimage.zoom(range(4),zf)
fy = scipy.ndimage.zoom(range(8),zf)

pcm = ax[7].pcolormesh(fx,fy,dd,cmap=cmap,vmin=vmin,vmax=vmax)
ax[7].axis('equal')
#ax[5].set_xlabel('M<---->L')
#ax[5].set_ylabel('P<----->A')
ax[7].spines['top'].set_visible(False)
ax[7].spines['right'].set_visible(False)
ax[7].spines['bottom'].set_visible(False)
ax[7].spines['left'].set_visible(False)
ax[7].set_xticks([])
ax[7].set_yticks([])
ax[7].set_title('+450')
##
mm = np.max(flexled02['gamma'][:,:,750:800],axis=-1)

zf = 2
dd = scipy.ndimage.zoom(mm, [zf,zf])
fx = scipy.ndimage.zoom(range(4),zf)
fy = scipy.ndimage.zoom(range(8),zf)

pcm = ax[8].pcolormesh(fx,fy,dd,cmap=cmap,vmin=vmin,vmax=vmax)
ax[8].axis('equal')
#ax[5].set_xlabel('M<---->L')
#ax[5].set_ylabel('P<----->A')
ax[8].spines['top'].set_visible(False)
ax[8].spines['right'].set_visible(False)
ax[8].spines['bottom'].set_visible(False)
ax[8].spines['left'].set_visible(False)
ax[8].set_xticks([])
ax[8].set_yticks([])
ax[8].set_title('+550')
##
mm = np.max(flexled02['gamma'][:,:,850:900],axis=-1)

zf = 2
dd = scipy.ndimage.zoom(mm, [zf,zf])
fx = scipy.ndimage.zoom(range(4),zf)
fy = scipy.ndimage.zoom(range(8),zf)

pcm = ax[9].pcolormesh(fx,fy,dd,cmap=cmap,vmin=vmin,vmax=vmax)
ax[9].axis('equal')
#ax[5].set_xlabel('M<---->L')
#ax[5].set_ylabel('P<----->A')
ax[9].spines['top'].set_visible(False)
ax[9].spines['right'].set_visible(False)
ax[9].spines['bottom'].set_visible(False)
ax[9].spines['left'].set_visible(False)
ax[9].set_xticks([])
ax[9].set_yticks([])
ax[9].set_title('+650')
fig.colorbar(pcm,ax=ax[-1],fraction=0.07, pad=-0.050)
